# %%
import dremio_client.lib as dlib

import pandas as pd
import h3pandas
import sqlserver_client.db_connector as dc
from datetime import datetime
import time

# %%
def getTag29Trnx(env):
    if env == 'UAT':
        engine = dc.getFastEngineUAT()
    elif env == 'PROD':
        engine = dc.getFastEnginePROD()
    else:
        engine = dc.getFastEngineLocal()

    query = f"""
        SELECT 
            date_trunc('month',created_at) as dt,
            src_name, MerchantName, 
            COUNT(*) AS total_trnx, 
            SUM(CASE WHEN ccy = 'KHR' THEN amount/4000.00 ELSE amount END) as total_usd_amount
        FROM "DataScience_DB"."General_DB".dbo.bk_outgoing
        where date_trunc('month',created_at) = '2023-12-01'
        and type = 'QR' AND MerchantType = '29'
        AND src_name <> MerchantName
        GROUP BY 1,2,3
        ORDER BY 3
        LIMIT 500000
        OFFSET 500000
    """

    np_df = dlib.simple_query(query)

    return np_df

# %%
def getAllAccountName(env):
    if env == 'UAT':
        engine = dc.getFastEngineUAT()
    elif env == 'PROD':
        engine = dc.getFastEnginePROD()
    else:
        engine = dc.getFastEngineLocal()

    query = f"""
        SELECT DISTINCT CIF, AC_NAME
        FROM dwh.FCCBOREP.VW_CUSTACC
        ORDER BY 1
    """

    np_df = dlib.simple_query(query)

    return np_df

# %%
tag29_df = getTag29Trnx('UAT')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tag29_df = getTag29Trnx('UAT')
#
# Cell In[2], line 3, in getTag29Trnx(env)
#       1 def getTag29Trnx(env):
#       2     if env == 'UAT':
# ----> 3         engine = dc.getFastEngineUAT()
#       4     elif env == 'PROD':
#       5         engine = dc.getFastEnginePROD()
#
# AttributeError: module 'sqlserver_client.db_connector' has no attribute 'getFastEngineUAT'

# %%
tag29_df.head()
# Out:
#           dt       src_name MerchantName  total_trnx total_usd_amount
# 0 2023-12-01    SREYNAN SOR                        1     10.000000000
# 1 2023-12-01    BONDOL KEAN                        1      5.000000000
# 2 2023-12-01   VOUCHLY VENG                        1     40.500000000
# 3 2023-12-01    SREYMOM KAY                        1     50.000000000
# 4 2023-12-01  LEAKHENA CHIN                        1     92.320000000

# %%
tag29_df['MerchantName'] = tag29_df['MerchantName'].str.upper()
tag29_df['MerchantName'] = tag29_df['MerchantName'].str.strip()

# %%
print(tag29_df.count())

print(tag29_df['total_trnx'].sum())

print(tag29_df['MerchantName'].nunique())
# Out:
# dt                  3160803
# src_name            3160803
# MerchantName        3160803
# total_trnx          3160803
# total_usd_amount    3160803
# dtype: int64
# 5912032
# 997060

# %%
tag29_df.head()
# Out:
#           dt       src_name MerchantName  total_trnx total_usd_amount
# 0 2023-12-01    SREYNAN SOR                        1     10.000000000
# 1 2023-12-01    BONDOL KEAN                        1      5.000000000
# 2 2023-12-01   VOUCHLY VENG                        1     40.500000000
# 3 2023-12-01    SREYMOM KAY                        1     50.000000000
# 4 2023-12-01  LEAKHENA CHIN                        1     92.320000000

# %%
unique_merchantname = pd.DataFrame({'Unique_MerchantName': tag29_df['MerchantName'].drop_duplicates()})

# %%
unique_merchantname.head(10)
# Out:
#    Unique_MerchantName
# 0
# 58        CHAN  SIPANA
# 59          RITH SEYHA
# 60              រី រ៉ន
# 61           សេង វណ្ណា
# 62         SAY BUNTHEA
# 63       TAING  KEMTRY
# 65         សោម ភត្រ្តា
# 66     CHHAIVAT DOEURN
# 67        CHHUN VANNET

# %%
unique_merchantname.count()
# Out:
# Unique_MerchantName    997060
# dtype: int64

# %%
aba_customers = getAllAccountName('UAT')

# %%
aba_customers.head()
# Out:
#                            AC_NAME
# 0  \tPENG KHEANG AND CHOU MUYSORTH
# 1                     \tRO SPHEARA
# 2     CAMBODIA CANAAN ORGANIZATION
# 3         MEL PHEAROM AND HOK BORA
# 4                     TES TITSORYA

# %%
aba_customers.count()
# Out:
# AC_NAME    object
# dtype: object

# %%
from rapidfuzz import fuzz as rf
# Token Sort Ratio is useful when word order might vary
def isABACustomer(str1,str2):
    return rf.token_sort_ratio(str1, str2)
    # return fuzz.token_sort_ratio(row['src_name'], row['MerchantName'])

# %%
for index_df1, row_df1 in unique_merchantname.iterrows():
    print('index_df1: ',index_df1)
    max_similarity_score = 0
    for index_df2, row_df2 in aba_customers.iterrows():        
        if index_df2 % 500000 == 0:
            print('index_df2: ',index_df2)
        # Apply the compare_strings function to each pair of rows
        similarity_score = isABACustomer(row_df1['Unique_MerchantName'], row_df2['AC_NAME'])
        # Update the 'Similarity Score' column if similarity score is higher
        if similarity_score >= 95:
            max_similarity_score = similarity_score 
            break
    unique_merchantname.at[index_df1, 'Max_Similarity_Score'] = max_similarity_score
# Out:
# index_df1:  0
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  58
# index_df2:  0
# index_df1:  59
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  60
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  61
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  62
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  63
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  65
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  66
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  67
# index_df2:  0
# index_df1:  68
# index_df2:  0
# index_df2:  500000
# index_df1:  73
# index_df2:  0
# index_df2:  500000
# index_df1:  74
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  93
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  97
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  98
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  99
# index_df2:  0
# index_df1:  100
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  101
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  102
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  103
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  104
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  105
# index_df2:  0
# index_df1:  106
# index_df2:  0
# index_df1:  107
# index_df2:  0
# index_df1:  108
# index_df2:  0
# index_df1:  109
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  110
# index_df2:  0
# index_df1:  111
# index_df2:  0
# index_df1:  112
# index_df2:  0
# index_df1:  113
# index_df2:  0
# index_df1:  114
# index_df2:  0
# index_df1:  121
# index_df2:  0
# index_df1:  122
# index_df2:  0
# index_df1:  123
# index_df2:  0
# index_df1:  124
# index_df2:  0
# index_df1:  127
# index_df2:  0
# index_df1:  129
# index_df2:  0
# index_df1:  130
# index_df2:  0
# index_df2:  500000
# index_df1:  131
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  132
# index_df2:  0
# index_df1:  138
# index_df2:  0
# index_df2:  500000
# index_df1:  139
# index_df2:  0
# index_df2:  500000
# index_df1:  145
# index_df2:  0
# index_df2:  500000
# index_df1:  149
# index_df2:  0
# index_df2:  500000
# index_df1:  150
# index_df2:  0
# index_df2:  500000
# index_df1:  151
# index_df2:  0
# index_df1:  154
# index_df2:  0
# index_df2:  500000
# index_df1:  155
# index_df2:  0
# index_df2:  500000
# index_df1:  156
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  157
# index_df2:  0
# index_df2:  500000
# index_df1:  158
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  159
# index_df2:  0
# index_df2:  500000
# index_df1:  160
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  185
# index_df2:  0
# index_df2:  500000
# index_df1:  186
# index_df2:  0
# index_df2:  500000
# index_df1:  187
# index_df2:  0
# index_df2:  500000
# index_df1:  189
# index_df2:  0
# index_df2:  500000
# index_df1:  191
# index_df2:  0
# index_df2:  500000
# index_df1:  192
# index_df2:  0
# index_df2:  500000
# index_df1:  196
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  199
# index_df2:  0
# index_df2:  500000
# index_df1:  200
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  201
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  202
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  226
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  227
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  231
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  233
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  234
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  235
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  236
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  237
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  238
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  240
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  241
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  242
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  243
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  244
# index_df2:  0
# index_df1:  245
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  246
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  251
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  252
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  253
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  254
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  255
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  257
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  259
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  261
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  262
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  266
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  267
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  268
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  269
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  273
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  274
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  275
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  276
# index_df2:  0
# index_df1:  312
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  313
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  314
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  315
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  316
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  317
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  318
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  322
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  324
# index_df2:  0
# index_df1:  326
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  327
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  330
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  331
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  332
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  337
# index_df2:  0
# index_df1:  338
# index_df2:  0
# index_df1:  339
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  341
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  342
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  343
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  344
# index_df2:  0
# index_df1:  345
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  346
# index_df2:  0
# index_df2:  500000
# index_df1:  358
# index_df2:  0
# index_df1:  359
# index_df2:  0
# index_df2:  500000
# index_df1:  360
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  362
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  363
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  469
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  470
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  484
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  485
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  486
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  489
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  490
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  491
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  492
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  501
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  503
# index_df2:  0
# index_df2:  500000
# index_df1:  504
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  506
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  507
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  508
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  509
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  511
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df1:  513
# index_df2:  0
# index_df1:  514
# index_df2:  0
# index_df2:  500000
# index_df1:  515
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  516
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  518
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  520
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  522
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  525
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  531
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  533
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  534
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  535
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  536
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  537
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  539
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  542
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  543
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  544
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  546
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  547
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  548
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  549
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  550
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  552
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  553
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  556
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  557
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  558
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  561
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  563
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  564
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  565
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  566
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  570
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  574
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  575
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  576
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  578
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  581
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  588
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  590
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  591
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  592
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  593
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  594
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  595
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  597
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  598
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  599
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  600
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  601
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  602
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  603
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  604
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  605
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  606
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  609
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  610
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  617
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  618
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  619
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  623
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  624
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  626
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  627
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  628
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  630
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  633
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  634
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  637
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  638
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  639
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  640
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  641
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  642
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  643
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  644
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  645
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  646
# index_df2:  0
# index_df2:  500000
# index_df1:  647
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  648
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  649
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  650
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  652
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  653
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  665
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  674
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  675
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  676
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  679
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  680
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  681
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  684
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  686
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  687
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  688
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  689
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  705
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  706
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  707
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  708
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  709
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  712
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  713
# index_df2:  0
# index_df1:  715
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  717
# index_df2:  0
# index_df1:  718
# index_df2:  0
# index_df1:  719
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  720
# index_df2:  0
# index_df1:  721
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  722
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  723
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  724
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  725
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  727
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  728
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  729
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  730
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  731
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  735
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df1:  736
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  737
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  738
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  743
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  744
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  745
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  746
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  747
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  752
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  753
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  757
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  758
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  759
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  760
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  761
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  762
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  768
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  769
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  776
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  777
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  778
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  779
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  780
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  781
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  782
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  783
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  784
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  785
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  787
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  788
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  789
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  799
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  800
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  801
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  802
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  803
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  804
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  805
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  806
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  807
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  808
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  809
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  810
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  811
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  812
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  813
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  814
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  817
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  819
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  820
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  821
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  822
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  823
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  827
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  831
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  832
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  833
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  834
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  840
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  842
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  843
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  845
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  847
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  848
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  849
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  850
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  854
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  855
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  856
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  866
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  870
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  871
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  875
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  876
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  883
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  887
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  890
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  895
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  896
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  904
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  905
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  906
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  907
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  909
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  910
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  912
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  913
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  914
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  923
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  927
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  930
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  934
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  935
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  938
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  939
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  940
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  941
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  943
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  944
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  947
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  949
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  951
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  952
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  953
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  954
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  955
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  957
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  958
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  959
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# index_df1:  960
# index_df2:  0
# index_df2:  500000
# index_df2:  1000000
# index_df2:  1500000
# index_df2:  2000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 8
#       6     print('index_df2: ',index_df2)
#       7 # Apply the compare_strings function to each pair of rows
# ----> 8 similarity_score = isABACustomer(row_df1['Unique_MerchantName'], row_df2['AC_NAME'])
#       9 # Update the 'Similarity Score' column if similarity score is higher
#      10 if similarity_score >= 95:
#
# File d:\Development\merchant_heatmap\env\lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File d:\Development\merchant_heatmap\env\lib\site-packages\pandas\core\series.py:1158, in Series._get_value(self, label, takeable)
#    1155 # Similar to Index.get_value, but we do not fall back to positional
#    1156 loc = self.index.get_loc(label)
# -> 1158 if is_integer(loc):
#    1159     return self._values[loc]
#    1161 if isinstance(self.index, MultiIndex):
#
# KeyboardInterrupt:

# %%
unique_merchantname
